# %% [markdown]
# # Python Practical Exam
#
# © Explore Data Science Academy
# ## Instructions to students
# * **DO NOT ADD / REMOVE CELLS FROM THIS NOTEBOOK, AND DO NOT CHANGE THE NAMES OF THE FUNCTIONS REQUIRED FOR TESTING.**
#
# * This exam consists of six questions. Each of the questions is independent and do not require you to use functions built from previous questions. You can answer the questions in any order you like.
#
# * Ensure that the answers to your questions do not contain `syntax` or `indentation` errors. Questions with these errors will break the auto grader and will mark the _**entire exam**_ as incorrect. The auto grader will give you an error message if this is the case. Use this error message to correct the offending code or comment it out before resubmitting.
# * You will be able to make _**multiple submissions**_ to the auto grader. Use this ability to check if a question you have answered is correct before proceeding to the next question.
# * Only place code in sections that contain the `# Your code here.` comment.
# * We have provided some expected outputs for your code. Use these to determine if your code behaves as intended.
# * Some questions may have multiple requirements. It is possible to receive partial marks in these questions, so if you get stuck, try to submit to the auto grader before moving on.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Section 1: Numerical computation
# ### Question 1
# We have a rope and want to cut the rope into four pieces to make a square. Given a rope of length $x$, what is the largest square (by area) that can be built given that a side of the square, $s$, can only be integer values? Units of measurement can be ignored. We are only interested in the numerical value of the solution.
# <p align="center">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/python_fundamentals/python_exam/Largest_Square_Rope.jpg"
#      alt="Largest Square"
#      style="float: center; padding-bottom=0.5em"
#      width=700px/>
#      <br>
#      <em>Figure 1: Area of the largest square enclosed by a rope. </em>
# </p>
#
# **Function specifications**
#
# *Argument(s):*
#
# - **x** `(float)` $\rightarrow$ the length of the rope.
#
# *Return:*
#
# - **area** `(int)` $\rightarrow$ the area of the square formed by the rope.
#
# > 💡**HINT**💡
# >
# >The perimeter of the square cannot exceed the length of the rope.

# %%
### START FUNCTION
def largest_square(x):
    # Your code here.
    length = int(x/4)
    area = length**2
    return area
### END FUNCTION

# %%
largest_square(41.5)
# Out:
# 100

# %%
largest_square(12) == 9
# Out:
# True

# %%
largest_square(324) == 6561
# Out:
# True

# %% [markdown]
# _**Expected outputs:**_
# ```python
# largest_square(12) == 9
# largest_square(41.5) == 100
# largest_square(324) == 6561
# ```

# %% [markdown]
# ### Question 2
# Given a square matrix of size $n\times n $ that only contains integers, compute the sum of the two diagonals. If the dimension of the square matrix is odd, make sure that you are not double-counting the value at the centre of the matrix.
#
# <p align="center">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/python_fundamentals/python_exam/Sum_of_diagonals.jpg"
#      alt="Sum of diagonals"
#      style="float: center; padding-bottom=0.5em"
#      width=50%/>
#      <br>
#      <em>Figure 2: Sum of diagonals.</em>
# </p>
#
#
# **Function specifications**
#
# *Arguments:*
# - **matrix** `(numpy.ndarray)` $\rightarrow$ input matrix to be used for computing the sum.
#
# *Return:*
# - **sum** `(int)` $\rightarrow$  return the sum of the two diagonals.

# %%
### START FUNCTION
def sum_of_diagonals(matrix):
    # Your code here.
    
    n = len(matrix)
    primary = []
    secondary = []
    i = 0
    while i < n:
        primary.append(matrix[i,i])
        secondary.append(matrix[i,n-1-i])
        i += 1
    
    centre = len(matrix)%2
    #if centre = 0, theres no double counting
    #if centre =1, theres double counting
    if centre == 1:
        #c = n//2
        del primary[n//2]
    
    diagonal_sum = sum(primary) + sum(secondary)
    
   
    return diagonal_sum #diag2
### END FUNCTION

# %%
matrix =np.random.randint(10,size=(5,5))
print(matrix)
sum_of_diagonals(matrix)
# Out:
# [[4 1 8 8 6]
#  [1 3 6 5 0]
#  [2 5 5 9 8]
#  [6 2 7 1 0]
#  [4 6 6 5 7]]
# 37

# %%
matrix = np.array([[7, 0, 8],
                   [6, 9, 1],
                   [3, 8, 4]])
sum_of_diagonals(matrix)==31
# Out:
# True

# %%
matrix = np.array([[4, 1, 1, 1],
                   [1, 3, 8, 0],
                   [0, 8, 5, 7],
                   [1, 6, 1, 3]])
sum_of_diagonals(matrix)==33
# Out:
# True

# %% [markdown]
# _**Expected outputs:**_
# ```python
# matrix = np.array([[7, 0, 8],
#                    [6, 9, 1],
#                    [3, 8, 4]])
# sum_of_diagonals(matrix)==31
#
#
# matrix = np.array([[4, 1, 1, 1],
#                    [1, 3, 8, 0],
#                    [0, 8, 5, 7],
#                    [1, 6, 1, 3]])
# sum_of_diagonals(matrix)==33
# ```

# %% [markdown]
# ## Section 2: Strings and lists
#
# ### Question 3:
#
# Write a function that computes the ratio of vowels vs. consonants ($\frac{vowels}{consonants}$) in a given sentence. The ratio should be given as a floating-point number rounded off to two decimal places. When writing your function, be sure to appropriately cater for the following punctuation marks:
# - apostrophes (')
# - quotations (")
# - full stops (.)
# - commas (,)
# - exclamations (!)
# - question marks (?)
# - colons (:)
# - semicolons (;)
#
# *Arguments:*
# - **sentence** `(string)` $\rightarrow$ sentence required to compute the ratio.
#
# *Return:*
# - **ratio** `(float)` $\rightarrow$ a ratio that describes the number of vowels to consonants: vowels/consonants.
#
# > 💡**HINT**💡
# >
# >Remember to cater for the white spaces that appear in your sentence.

# %%
### START FUNCTION
def vowel_consonant_ratio(sentence):
    # Your code here.
    stripped_sentence = list(sentence.lower().strip())
    vowel = ['a','e','i','o','u']
    vowels = []
    consonants = []
    
    for i in stripped_sentence:
        if i not in vowel:
            consonants.append(i)
        else:
            vowels.append(i)
    
    consonant = ['b','c','d','f','g','h','j','k','l','m','n','p','q','r','s','t','v','w','x','y','z']
    
    for j in consonants:
        if j not in consonant:
            consonants.remove(j)
    
    for j in consonants:
        if j not in consonant:
            consonants.remove(j)
    
    #consonants.strip()
    vowel_no = len(vowels)
    consonant_no = len(consonants)
    ratio = round(vowel_no/consonant_no,2)
    return ratio
### END FUNCTION

# %%
vowel_consonant_ratio("Thomas! Where have you been?")
# Out:
# 0.83

# %%
vowel_consonant_ratio("This is a random sentence!")
# Out:
# 0.62

# %% [markdown]
# ***Expected outputs***
#
# ```python
# vowel_consonant_ratio("This is a random sentence!")==0.62
# vowel_consonant_ratio("Thomas! Where have you been?")==0.83
# ```

# %% [markdown]
# ### Question 4
#
# Write a function that will redact every third word in a sentence. Make use of the hashtag (`#`) symbol to redact the characters that make up the word, i.e. if the word is five characters long then a string of five hashtags should replace that word. However, this should not redact any of the following punctuation marks:
# - apostrophes (')
# - quotations (")
# - full stops (.)
# - commas (,)
# - exclamations (!)
# - question marks (?)
# - colons (:)
# - semicolons (;)
#
# *Arguments:*
# - **sentence** `(string)` $\rightarrow$ sentence that needs to be redacted.
#
# *Return:*
# - **redacted sentence** `(string)`$\rightarrow$ every third word should be redacted.

# %%
### START FUNCTION
def redact_words(sentence):
    # Your code here.
    return redacted_sentence
### END FUNCTION

# %%
sentence = "Explorer, this is why you shouldn't come to a test unprepared."
redact_words(sentence)

# %% [markdown]
# ***Expected outputs***
#
# ```python
# sentence = "My dear Explorer, do you understand the nature of the given question?"
# redact_words(sentence) ==  'My dear ########, do you ########## the nature ## the given ########?'
#
# sentence = "Explorer, this is why you shouldn't come to a test unprepared."
# redact_words(sentence)=="Explorer, this ## why you #######'# come to # test unprepared."
#
# ```

# %% [markdown]
# ### Question 5
#
# Given an alphanumeric list, separate it into three different lists stored in a dictionary:
#
# - The first list should only contain lowercase letters.
# - The second list should only contain uppercase letters.
# - The third list should only contain numbers.
#
# Each list stored in the dictionary should be stored in ascending order. Use the following naming convention when creating your lists:
# - numbers
# - uppercase
# - lowercase
#
# Make sure that you adhere to the above instruction, as the name of your lists will be used to mark your function.
#
# *Arguments:*
# - **character_list:** `(list)` $\rightarrow$ list of alphanumeric characters.
#
# *Return:*
# - **dictionary** `(dict)` $\rightarrow$  dictionary containing all three lists.

# %%
### START FUNCTION
def create_dictionary(character_list):
    # Your code here.
    nums = []
    alpha = []
    for i in character_list:
        if type(i) == str:
            alpha.append(i)
        else:
            nums.append(i)
    
    sort_num = sorted(nums)
    lows = [x for x in alpha if x.islower()]
    highs = [x for x in alpha if x.isupper()]
    lows.sort()
    highs.sort()
    dictionary = {'numbers': sort_num,'uppercase': highs, 'lowercase': lows}
    return dictionary #nums, alpha, low, high
### END FUNCTION

# %%
lst = [2,'j','K','o',6,'x',5,'A',3.2]
create_dictionary(lst)
# Out:
# {'numbers': [2, 3.2, 5, 6],
#  'uppercase': ['A', 'K'],
#  'lowercase': ['j', 'o', 'x']}

# %% [markdown]
# ***Expected outputs***
#
# ```python
# lst = [2,'j','K','o',6,'x',5,'A',3.2]
# create_dictionary(lst)
#
# {'numbers': [2, 3.2, 5, 6],
#  'uppercase': ['A', 'K'],
#  'lowercase': ['j', 'o', 'x']}
#  ```

# %% [markdown]
# ## Section 3: DataFrames
# You will need the below DataFrames to answer the following questions.
#
# _**DO NOT ALTER THESE DATAFRAMES, AS DOING SO CAN LEAD TO A NEGATIVE MARK.**_

# %%
country_map_df = pd.read_csv('https://raw.githubusercontent.com/Explore-AI/Public-Data/master/AnalyseProject/country_code_map.csv', index_col='Country Code')
population_df = pd.read_csv('https://raw.githubusercontent.com/Explore-AI/Public-Data/master/AnalyseProject/world_population.csv', index_col='Country Code')
meta_df = pd.read_csv('https://raw.githubusercontent.com/Explore-AI/Public-Data/master/AnalyseProject/metadata.csv', index_col='Country Code')

# %% [markdown]
# _**DataFrame specifications:**_
#
# The DataFrames provide information about the population of the world for various years. Some things to note:
# * All DataFrames have a `Country Code` as an index, which is a three-letter code referring to a country.
# * The `country_map_df` data maps the `Country Code` to a `Country Name`.
# * The `population_df` data contains information on the population for a given country between the years 1960 and 2017.
# * The `meta_df` data contains meta-information about each country, including its geographical region, its income group, and a comment on the country as a whole.

# %% [markdown]
# ### Question 6
#
# Write a function that will return a list of countries for a specified region and income group. If the specified region and income group do not return a country, return `None` as the value.
#
#
# **Function specifications**
#
# *Argument(s):*
# - **region** `(string)` $\rightarrow$ the region you want to query.
# - **income_group** `(string)` $\rightarrow$ the income group you want to query.
#
#
# *Return:*
# - **countries** `(list)` $\rightarrow$ return a list of countries that match the search criteria or **`None`** if no countries are found.

# %%
country_map_df
# Out:
#               Country Name
# Country Code
# ABW                  Aruba
# AFG            Afghanistan
# AGO                 Angola
# ALB                Albania
# AND                Andorra
# ...                    ...
# XKX                 Kosovo
# YEM            Yemen, Rep.
# ZAF           South Africa
# ZMB                 Zambia
# ZWE               Zimbabwe
#
# [217 rows x 1 columns]

# %%
meta_df
# Out:
#                                   Region         Income Group  \
# Country Code
# ABW            Latin America & Caribbean          High income
# AFG                           South Asia           Low income
# AGO                   Sub-Saharan Africa  Lower middle income
# ALB                Europe & Central Asia  Upper middle income
# AND                Europe & Central Asia          High income
# ...                                  ...                  ...
# XKX                Europe & Central Asia  Lower middle income
# YEM           Middle East & North Africa           Low income
# ZAF                   Sub-Saharan Africa  Upper middle income
# ZMB                   Sub-Saharan Africa  Lower middle income
# ZWE                   Sub-Saharan Africa           Low income
#
#                                                   Special Notes
# Country Code
# ABW           Mining is included in agriculture\r\r\r\nElect...
# AFG           Fiscal year end: March 20; reporting period fo...
# AGO                                                         NaN
# ALB                                                         NaN
# AND           WB-3 code changed from ADO to AND to align wit...
# ...                                                         ...
# XKX           WB-3 code changed from KSV to XKX to align wit...
# YEM           Based on official government statistics and In...
# ZAF           Fiscal year end: March 31; reporting period fo...
# ZMB           The base year is 2010. National accounts data ...
# ZWE           Base year change from 2009 to 2012 - national ...
#
# [217 rows x 3 columns]

# %%
### START FUNCTION
def find_countries_by_region_and_income(region,income_group):
    # Your code here.
    #get country codes
    country_codes = []
    for i in meta_df['Region'].iloc:
        for index in meta_df.iloc:
            if region == i:
                country_codes.append(index)
    
    = country_codes.map(lambda x: (i[1:] for i in  if i.startswith('@')))
    return country_codes
### END FUNCTION

# %%
countries = find_countries_by_region_and_income('Sub-Saharan Africa','Upper middle income')
countries
# Out:
# [Region                                   Latin America & Caribbean
#  Income Group                                           High income
#  Special Notes    Mining is included in agriculture\r\r\r\nElect...
#  Name: ABW, dtype: object,
#  Region                                                  South Asia
#  Income Group                                            Low income
#  Special Notes    Fiscal year end: March 20; reporting period fo...
#  Name: AFG, dtype: object,
#  Region            Sub-Saharan Africa
#  Income Group     Lower middle income
#  Special Notes                    NaN
#  Name: AGO, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Upper middle income
#  Special Notes                      NaN
#  Name: ALB, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    WB-3 code changed from ADO to AND to align wit...
#  Name: AND, dtype: object,
#  Region           Middle East & North Africa
#  Income Group                    High income
#  Special Notes                           NaN
#  Name: ARE, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                           High income
#  Special Notes    Series of GNI and GNDI from 1993-2017 have bee...
#  Name: ARG, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Upper middle income
#  Special Notes                      NaN
#  Name: ARM, dtype: object,
#  Region           East Asia & Pacific
#  Income Group     Upper middle income
#  Special Notes     New base Year 2009
#  Name: ASM, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group                   High income
#  Special Notes                          NaN
#  Name: ATG, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                           High income
#  Special Notes    Fiscal year end: June 30; reporting period for...
#  Name: AUS, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: AUT, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Upper middle income
#  Special Notes                      NaN
#  Name: AZE, dtype: object,
#  Region           Sub-Saharan Africa
#  Income Group             Low income
#  Special Notes                   NaN
#  Name: BDI, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: BEL, dtype: object,
#  Region           Sub-Saharan Africa
#  Income Group             Low income
#  Special Notes                   NaN
#  Name: BEN, dtype: object,
#  Region           Sub-Saharan Africa
#  Income Group             Low income
#  Special Notes                   NaN
#  Name: BFA, dtype: object,
#  Region                                                  South Asia
#  Income Group                                   Lower middle income
#  Special Notes    Fiscal year end: June 30; reporting period for...
#  Name: BGD, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Upper middle income
#  Special Notes                      NaN
#  Name: BGR, dtype: object,
#  Region           Middle East & North Africa
#  Income Group                    High income
#  Special Notes                           NaN
#  Name: BHR, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group                   High income
#  Special Notes                          NaN
#  Name: BHS, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Upper middle income
#  Special Notes                      NaN
#  Name: BIH, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                   Upper middle income
#  Special Notes    Data before 2015 were adjusted to reflect the ...
#  Name: BLR, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes                          NaN
#  Name: BLZ, dtype: object,
#  Region           North America
#  Income Group       High income
#  Special Notes              NaN
#  Name: BMU, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Lower middle income
#  Special Notes                          NaN
#  Name: BOL, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                   Upper middle income
#  Special Notes    Change in reference year from 2000 to 2010.  \...
#  Name: BRA, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                           High income
#  Special Notes    Constant and current series between 1975-2017 ...
#  Name: BRB, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                           High income
#  Special Notes    National accounts revision is based on data fr...
#  Name: BRN, dtype: object,
#  Region                    South Asia
#  Income Group     Lower middle income
#  Special Notes                    NaN
#  Name: BTN, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                   Upper middle income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: BWA, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    The source of national accounts has changed to...
#  Name: CAF, dtype: object,
#  Region                                               North America
#  Income Group                                           High income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: CAN, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: CHE, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: CHI, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                           High income
#  Special Notes    Before 1996, for current series, components of...
#  Name: CHL, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                   Upper middle income
#  Special Notes    On 1 July 1997 China resumed its exercise of s...
#  Name: CHN, dtype: object,
#  Region            Sub-Saharan Africa
#  Income Group     Lower middle income
#  Special Notes                    NaN
#  Name: CIV, dtype: object,
#  Region                                       Sub-Saharan Africa
#  Income Group                                Lower middle income
#  Special Notes    National accounts data revised from 1993-2016.
#  Name: CMR, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    WB-3 code changed from ZAR to COD to align wit...
#  Name: COD, dtype: object,
#  Region            Sub-Saharan Africa
#  Income Group     Lower middle income
#  Special Notes                    NaN
#  Name: COG, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                   Upper middle income
#  Special Notes    Constant series have been calculated using rel...
#  Name: COL, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    Base year change from 1990 to 2007 -  national...
#  Name: COM, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                   Lower middle income
#  Special Notes    Cabo Verde is the name for the country previou...
#  Name: CPV, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                   Upper middle income
#  Special Notes    National accounts are revised from 1991 to 201...
#  Name: CRI, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                   Upper middle income
#  Special Notes    Based on government statistics, the base year ...
#  Name: CUB, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group                   High income
#  Special Notes                          NaN
#  Name: CUW, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group                   High income
#  Special Notes                          NaN
#  Name: CYM, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: CYP, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: CZE, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: DEU, dtype: object,
#  Region           Middle East & North Africa
#  Income Group            Lower middle income
#  Special Notes                           NaN
#  Name: DJI, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes                          NaN
#  Name: DMA, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: DNK, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                   Upper middle income
#  Special Notes    The Dominican Republic uses chain linked metho...
#  Name: DOM, dtype: object,
#  Region           Middle East & North Africa
#  Income Group            Upper middle income
#  Special Notes                           NaN
#  Name: DZA, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes                          NaN
#  Name: ECU, dtype: object,
#  Region                                  Middle East & North Africa
#  Income Group                                   Lower middle income
#  Special Notes    The data from 1973 to 1979 is calendar year da...
#  Name: EGY, dtype: object,
#  Region           Sub-Saharan Africa
#  Income Group             Low income
#  Special Notes                   NaN
#  Name: ERI, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: ESP, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: EST, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    Fiscal year end: July 7; reporting period for ...
#  Name: ETH, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: FIN, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                   Upper middle income
#  Special Notes    National accounts have been revised  based on ...
#  Name: FJI, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: FRA, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: FRO, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                   Lower middle income
#  Special Notes    Fiscal year ends on September 30; reporting pe...
#  Name: FSM, dtype: object,
#  Region            Sub-Saharan Africa
#  Income Group     Upper middle income
#  Special Notes                    NaN
#  Name: GAB, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: GBR, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Lower middle income
#  Special Notes                      NaN
#  Name: GEO, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                   Lower middle income
#  Special Notes    Base year change from 2006 to 2013 - national ...
#  Name: GHA, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: GIB, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    Base Year is 2003 and 2010 is the Reference Ye...
#  Name: GIN, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    Base year change from 2004 to 2013 - national ...
#  Name: GMB, dtype: object,
#  Region           Sub-Saharan Africa
#  Income Group             Low income
#  Special Notes                   NaN
#  Name: GNB, dtype: object,
#  Region            Sub-Saharan Africa
#  Income Group     Upper middle income
#  Special Notes                    NaN
#  Name: GNQ, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: GRC, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes                          NaN
#  Name: GRD, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: GRL, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes       The base year is 2001.
#  Name: GTM, dtype: object,
#  Region           East Asia & Pacific
#  Income Group             High income
#  Special Notes                    NaN
#  Name: GUM, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes                          NaN
#  Name: GUY, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                           High income
#  Special Notes    On 1 July 1997 China resumed its exercise of s...
#  Name: HKG, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Lower middle income
#  Special Notes                          NaN
#  Name: HND, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: HRV, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                            Low income
#  Special Notes    Fiscal year end: September 30; reporting perio...
#  Name: HTI, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: HUN, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                   Lower middle income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: IDN, dtype: object,
#  Region                         Europe & Central Asia
#  Income Group                             High income
#  Special Notes    Base year has been changed to 2016.
#  Name: IMN, dtype: object,
#  Region                                                  South Asia
#  Income Group                                   Lower middle income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: IND, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: IRL, dtype: object,
#  Region                                  Middle East & North Africa
#  Income Group                                   Upper middle income
#  Special Notes    Fiscal year end: March 20; reporting period fo...
#  Name: IRN, dtype: object,
#  Region                                  Middle East & North Africa
#  Income Group                                   Upper middle income
#  Special Notes    Based on official government statistics, the n...
#  Name: IRQ, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: ISL, dtype: object,
#  Region           Middle East & North Africa
#  Income Group                    High income
#  Special Notes                           NaN
#  Name: ISR, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: ITA, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes                          NaN
#  Name: JAM, dtype: object,
#  Region                                  Middle East & North Africa
#  Income Group                                   Upper middle income
#  Special Notes    Expenditure data from 2010 removed as they are...
#  Name: JOR, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                           High income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: JPN, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Upper middle income
#  Special Notes                      NaN
#  Name: KAZ, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                   Lower middle income
#  Special Notes    Fiscal year end: June 30; reporting period for...
#  Name: KEN, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Lower middle income
#  Special Notes                      NaN
#  Name: KGZ, dtype: object,
#  Region           East Asia & Pacific
#  Income Group     Lower middle income
#  Special Notes                    NaN
#  Name: KHM, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                   Lower middle income
#  Special Notes    Based on IMF and World Bank Country team, GDP ...
#  Name: KIR, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group                   High income
#  Special Notes                          NaN
#  Name: KNA, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                           High income
#  Special Notes    The new base year is 2010. GDP data are availa...
#  Name: KOR, dtype: object,
#  Region                                  Middle East & North Africa
#  Income Group                                           High income
#  Special Notes    Fiscal year end: June 30; reporting period for...
#  Name: KWT, dtype: object,
#  Region           East Asia & Pacific
#  Income Group     Lower middle income
#  Special Notes    New base Year 2012.
#  Name: LAO, dtype: object,
#  Region                Middle East & North Africa
#  Income Group                 Upper middle income
#  Special Notes    The new reference year is 2010.
#  Name: LBN, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    National accounts local currency data have bee...
#  Name: LBR, dtype: object,
#  Region                                  Middle East & North Africa
#  Income Group                                   Upper middle income
#  Special Notes    Official statistics for Libya are not availabl...
#  Name: LBY, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                   Upper middle income
#  Special Notes    St. Lucia has changed the data source from Eas...
#  Name: LCA, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: LIE, dtype: object,
#  Region                                                  South Asia
#  Income Group                                   Lower middle income
#  Special Notes    Bureau of Census and Statistics revised nation...
#  Name: LKA, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                   Lower middle income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: LSO, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: LTU, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: LUX, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: LVA, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                           High income
#  Special Notes    On 20 December 1999 China resumed its exercise...
#  Name: MAC, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group                   High income
#  Special Notes                          NaN
#  Name: MAF, dtype: object,
#  Region           Middle East & North Africa
#  Income Group            Lower middle income
#  Special Notes                           NaN
#  Name: MAR, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: MCO, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Lower middle income
#  Special Notes                      NaN
#  Name: MDA, dtype: object,
#  Region           Sub-Saharan Africa
#  Income Group             Low income
#  Special Notes                   NaN
#  Name: MDG, dtype: object,
#  Region                    South Asia
#  Income Group     Upper middle income
#  Special Notes                    NaN
#  Name: MDV, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes                          NaN
#  Name: MEX, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                   Upper middle income
#  Special Notes    Fiscal year ends on September 30; reporting pe...
#  Name: MHL, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Upper middle income
#  Special Notes                      NaN
#  Name: MKD, dtype: object,
#  Region                   Sub-Saharan Africa
#  Income Group                     Low income
#  Special Notes    The new base year is 1999.
#  Name: MLI, dtype: object,
#  Region                                  Middle East & North Africa
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: MLT, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                   Lower middle income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: MMR, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                   Upper middle income
#  Special Notes    Montenegro declared independence from Serbia a...
#  Name: MNE, dtype: object,
#  Region           East Asia & Pacific
#  Income Group     Lower middle income
#  Special Notes                    NaN
#  Name: MNG, dtype: object,
#  Region           East Asia & Pacific
#  Income Group             High income
#  Special Notes                    NaN
#  Name: MNP, dtype: object,
#  Region           Sub-Saharan Africa
#  Income Group             Low income
#  Special Notes                   NaN
#  Name: MOZ, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                   Lower middle income
#  Special Notes    Based on official statistics from the Ministry...
#  Name: MRT, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                   Upper middle income
#  Special Notes    Authorities made significant revisions to the ...
#  Name: MUS, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: MWI, dtype: object,
#  Region           East Asia & Pacific
#  Income Group     Upper middle income
#  Special Notes                    NaN
#  Name: MYS, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                   Upper middle income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: NAM, dtype: object,
#  Region           East Asia & Pacific
#  Income Group             High income
#  Special Notes                    NaN
#  Name: NCL, dtype: object,
#  Region                                 Sub-Saharan Africa
#  Income Group                                   Low income
#  Special Notes    Value added is measured in basic prices.
#  Name: NER, dtype: object,
#  Region            Sub-Saharan Africa
#  Income Group     Lower middle income
#  Special Notes                    NaN
#  Name: NGA, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                   Lower middle income
#  Special Notes    Country has 1994 as the base year and 2006 as ...
#  Name: NIC, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: NLD, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: NOR, dtype: object,
#  Region                                                  South Asia
#  Income Group                                            Low income
#  Special Notes    Fiscal year end: July 14; reporting period for...
#  Name: NPL, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                   Upper middle income
#  Special Notes    Fiscal year end: June 30; reporting period for...
#  Name: NRU, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                           High income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: NZL, dtype: object,
#  Region                                  Middle East & North Africa
#  Income Group                                           High income
#  Special Notes    National Center for Statistics and Information...
#  Name: OMN, dtype: object,
#  Region                                                  South Asia
#  Income Group                                   Lower middle income
#  Special Notes    Fiscal year end: June 30; reporting period for...
#  Name: PAK, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                           High income
#  Special Notes    Based on government statistics national accoun...
#  Name: PAN, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes                          NaN
#  Name: PER, dtype: object,
#  Region           East Asia & Pacific
#  Income Group     Lower middle income
#  Special Notes                    NaN
#  Name: PHL, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                           High income
#  Special Notes    Fiscal year ends on September 30; reporting pe...
#  Name: PLW, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                   Lower middle income
#  Special Notes    Based on revised data from the National Statis...
#  Name: PNG, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: POL, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                           High income
#  Special Notes    Fiscal year end: June 30; reporting period for...
#  Name: PRI, dtype: object,
#  Region           East Asia & Pacific
#  Income Group              Low income
#  Special Notes                    NaN
#  Name: PRK, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: PRT, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes                          NaN
#  Name: PRY, dtype: object,
#  Region                                  Middle East & North Africa
#  Income Group                                   Lower middle income
#  Special Notes    WB-3 code changed from WBG to PSE to align wit...
#  Name: PSE, dtype: object,
#  Region           East Asia & Pacific
#  Income Group             High income
#  Special Notes                    NaN
#  Name: PYF, dtype: object,
#  Region           Middle East & North Africa
#  Income Group                    High income
#  Special Notes                           NaN
#  Name: QAT, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                   Upper middle income
#  Special Notes    WB-3 code changed from ROM to ROU to align wit...
#  Name: ROU, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Upper middle income
#  Special Notes                      NaN
#  Name: RUS, dtype: object,
#  Region                   Sub-Saharan Africa
#  Income Group                     Low income
#  Special Notes    The New Base Year is 2014.
#  Name: RWA, dtype: object,
#  Region                                  Middle East & North Africa
#  Income Group                                           High income
#  Special Notes    Based on data from the Saudi Central Departmen...
#  Name: SAU, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                   Lower middle income
#  Special Notes    Demographic data (total population, life expec...
#  Name: SDN, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    Base year change from 1999 to 2014 - national ...
#  Name: SEN, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                           High income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: SGP, dtype: object,
#  Region           East Asia & Pacific
#  Income Group     Lower middle income
#  Special Notes                    NaN
#  Name: SLB, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    Fiscal year end: June 30; reporting period for...
#  Name: SLE, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Lower middle income
#  Special Notes                          NaN
#  Name: SLV, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: SMR, dtype: object,
#  Region           Sub-Saharan Africa
#  Income Group             Low income
#  Special Notes                   NaN
#  Name: SOM, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                   Upper middle income
#  Special Notes    The data for 2015-2017 does not reflect the St...
#  Name: SRB, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    South Sudan declared its independence on July ...
#  Name: SSD, dtype: object,
#  Region                   Sub-Saharan Africa
#  Income Group            Lower middle income
#  Special Notes    The new base year is 2008.
#  Name: STP, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes                          NaN
#  Name: SUR, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: SVK, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: SVN, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    Fiscal year end: June 30; reporting period for...
#  Name: SWE, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                   Lower middle income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: SWZ, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group                   High income
#  Special Notes                          NaN
#  Name: SXM, dtype: object,
#  Region           Sub-Saharan Africa
#  Income Group            High income
#  Special Notes                   NaN
#  Name: SYC, dtype: object,
#  Region           Middle East & North Africa
#  Income Group                     Low income
#  Special Notes                           NaN
#  Name: SYR, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group                   High income
#  Special Notes                          NaN
#  Name: TCA, dtype: object,
#  Region           Sub-Saharan Africa
#  Income Group             Low income
#  Special Notes                   NaN
#  Name: TCD, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    Base year change from 2000 to 2007 - national ...
#  Name: TGO, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                   Upper middle income
#  Special Notes    Fiscal year end: September 30; reporting perio...
#  Name: THA, dtype: object,
#  Region           Europe & Central Asia
#  Income Group                Low income
#  Special Notes                      NaN
#  Name: TJK, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Upper middle income
#  Special Notes                      NaN
#  Name: TKM, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                   Lower middle income
#  Special Notes    WB-3 code changed from TMP to TLS to align wit...
#  Name: TLS, dtype: object,
#  Region           East Asia & Pacific
#  Income Group     Upper middle income
#  Special Notes                    NaN
#  Name: TON, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group                   High income
#  Special Notes                          NaN
#  Name: TTO, dtype: object,
#  Region           Middle East & North Africa
#  Income Group            Lower middle income
#  Special Notes                           NaN
#  Name: TUN, dtype: object,
#  Region               Europe & Central Asia
#  Income Group           Upper middle income
#  Special Notes    The new base year is 2009
#  Name: TUR, dtype: object,
#  Region           East Asia & Pacific
#  Income Group     Upper middle income
#  Special Notes                    NaN
#  Name: TUV, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    Tanzania reports using a blend of SNA 1993 and...
#  Name: TZA, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    Fiscal year end: June 30; reporting period for...
#  Name: UGA, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Lower middle income
#  Special Notes                      NaN
#  Name: UKR, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group                   High income
#  Special Notes                          NaN
#  Name: URY, dtype: object,
#  Region           North America
#  Income Group       High income
#  Special Notes              NaN
#  Name: USA, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Lower middle income
#  Special Notes                      NaN
#  Name: UZB, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes                          NaN
#  Name: VCT, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes                          NaN
#  Name: VEN, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group                   High income
#  Special Notes                          NaN
#  Name: VGB, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group                   High income
#  Special Notes                          NaN
#  Name: VIR, dtype: object,
#  Region           East Asia & Pacific
#  Income Group     Lower middle income
#  Special Notes                    NaN
#  Name: VNM, dtype: object,
#  Region           East Asia & Pacific
#  Income Group     Lower middle income
#  Special Notes                    NaN
#  Name: VUT, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                   Upper middle income
#  Special Notes    Fiscal year ends on June 30; reporting period ...
#  Name: WSM, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                   Lower middle income
#  Special Notes    WB-3 code changed from KSV to XKX to align wit...
#  Name: XKX, dtype: object,
#  Region                                  Middle East & North Africa
#  Income Group                                            Low income
#  Special Notes    Based on official government statistics and In...
#  Name: YEM, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                   Upper middle income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: ZAF, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                   Lower middle income
#  Special Notes    The base year is 2010. National accounts data ...
#  Name: ZMB, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    Base year change from 2009 to 2012 - national ...
#  Name: ZWE, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                           High income
#  Special Notes    Mining is included in agriculture\r\r\r\nElect...
#  Name: ABW, dtype: object,
#  Region                                                  South Asia
#  Income Group                                            Low income
#  Special Notes    Fiscal year end: March 20; reporting period fo...
#  Name: AFG, dtype: object,
#  Region            Sub-Saharan Africa
#  Income Group     Lower middle income
#  Special Notes                    NaN
#  Name: AGO, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Upper middle income
#  Special Notes                      NaN
#  Name: ALB, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    WB-3 code changed from ADO to AND to align wit...
#  Name: AND, dtype: object,
#  Region           Middle East & North Africa
#  Income Group                    High income
#  Special Notes                           NaN
#  Name: ARE, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                           High income
#  Special Notes    Series of GNI and GNDI from 1993-2017 have bee...
#  Name: ARG, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Upper middle income
#  Special Notes                      NaN
#  Name: ARM, dtype: object,
#  Region           East Asia & Pacific
#  Income Group     Upper middle income
#  Special Notes     New base Year 2009
#  Name: ASM, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group                   High income
#  Special Notes                          NaN
#  Name: ATG, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                           High income
#  Special Notes    Fiscal year end: June 30; reporting period for...
#  Name: AUS, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: AUT, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Upper middle income
#  Special Notes                      NaN
#  Name: AZE, dtype: object,
#  Region           Sub-Saharan Africa
#  Income Group             Low income
#  Special Notes                   NaN
#  Name: BDI, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: BEL, dtype: object,
#  Region           Sub-Saharan Africa
#  Income Group             Low income
#  Special Notes                   NaN
#  Name: BEN, dtype: object,
#  Region           Sub-Saharan Africa
#  Income Group             Low income
#  Special Notes                   NaN
#  Name: BFA, dtype: object,
#  Region                                                  South Asia
#  Income Group                                   Lower middle income
#  Special Notes    Fiscal year end: June 30; reporting period for...
#  Name: BGD, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Upper middle income
#  Special Notes                      NaN
#  Name: BGR, dtype: object,
#  Region           Middle East & North Africa
#  Income Group                    High income
#  Special Notes                           NaN
#  Name: BHR, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group                   High income
#  Special Notes                          NaN
#  Name: BHS, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Upper middle income
#  Special Notes                      NaN
#  Name: BIH, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                   Upper middle income
#  Special Notes    Data before 2015 were adjusted to reflect the ...
#  Name: BLR, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes                          NaN
#  Name: BLZ, dtype: object,
#  Region           North America
#  Income Group       High income
#  Special Notes              NaN
#  Name: BMU, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Lower middle income
#  Special Notes                          NaN
#  Name: BOL, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                   Upper middle income
#  Special Notes    Change in reference year from 2000 to 2010.  \...
#  Name: BRA, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                           High income
#  Special Notes    Constant and current series between 1975-2017 ...
#  Name: BRB, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                           High income
#  Special Notes    National accounts revision is based on data fr...
#  Name: BRN, dtype: object,
#  Region                    South Asia
#  Income Group     Lower middle income
#  Special Notes                    NaN
#  Name: BTN, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                   Upper middle income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: BWA, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    The source of national accounts has changed to...
#  Name: CAF, dtype: object,
#  Region                                               North America
#  Income Group                                           High income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: CAN, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: CHE, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: CHI, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                           High income
#  Special Notes    Before 1996, for current series, components of...
#  Name: CHL, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                   Upper middle income
# ...
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: CYP, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: CZE, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: DEU, dtype: object,
#  Region           Middle East & North Africa
#  Income Group            Lower middle income
#  Special Notes                           NaN
#  Name: DJI, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes                          NaN
#  Name: DMA, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: DNK, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                   Upper middle income
#  Special Notes    The Dominican Republic uses chain linked metho...
#  Name: DOM, dtype: object,
#  Region           Middle East & North Africa
#  Income Group            Upper middle income
#  Special Notes                           NaN
#  Name: DZA, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes                          NaN
#  Name: ECU, dtype: object,
#  Region                                  Middle East & North Africa
#  Income Group                                   Lower middle income
#  Special Notes    The data from 1973 to 1979 is calendar year da...
#  Name: EGY, dtype: object,
#  Region           Sub-Saharan Africa
#  Income Group             Low income
#  Special Notes                   NaN
#  Name: ERI, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: ESP, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: EST, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    Fiscal year end: July 7; reporting period for ...
#  Name: ETH, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: FIN, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                   Upper middle income
#  Special Notes    National accounts have been revised  based on ...
#  Name: FJI, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: FRA, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: FRO, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                   Lower middle income
#  Special Notes    Fiscal year ends on September 30; reporting pe...
#  Name: FSM, dtype: object,
#  Region            Sub-Saharan Africa
#  Income Group     Upper middle income
#  Special Notes                    NaN
#  Name: GAB, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: GBR, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Lower middle income
#  Special Notes                      NaN
#  Name: GEO, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                   Lower middle income
#  Special Notes    Base year change from 2006 to 2013 - national ...
#  Name: GHA, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: GIB, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    Base Year is 2003 and 2010 is the Reference Ye...
#  Name: GIN, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    Base year change from 2004 to 2013 - national ...
#  Name: GMB, dtype: object,
#  Region           Sub-Saharan Africa
#  Income Group             Low income
#  Special Notes                   NaN
#  Name: GNB, dtype: object,
#  Region            Sub-Saharan Africa
#  Income Group     Upper middle income
#  Special Notes                    NaN
#  Name: GNQ, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: GRC, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes                          NaN
#  Name: GRD, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: GRL, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes       The base year is 2001.
#  Name: GTM, dtype: object,
#  Region           East Asia & Pacific
#  Income Group             High income
#  Special Notes                    NaN
#  Name: GUM, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes                          NaN
#  Name: GUY, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                           High income
#  Special Notes    On 1 July 1997 China resumed its exercise of s...
#  Name: HKG, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Lower middle income
#  Special Notes                          NaN
#  Name: HND, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: HRV, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                            Low income
#  Special Notes    Fiscal year end: September 30; reporting perio...
#  Name: HTI, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: HUN, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                   Lower middle income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: IDN, dtype: object,
#  Region                         Europe & Central Asia
#  Income Group                             High income
#  Special Notes    Base year has been changed to 2016.
#  Name: IMN, dtype: object,
#  Region                                                  South Asia
#  Income Group                                   Lower middle income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: IND, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: IRL, dtype: object,
#  Region                                  Middle East & North Africa
#  Income Group                                   Upper middle income
#  Special Notes    Fiscal year end: March 20; reporting period fo...
#  Name: IRN, dtype: object,
#  Region                                  Middle East & North Africa
#  Income Group                                   Upper middle income
#  Special Notes    Based on official government statistics, the n...
#  Name: IRQ, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: ISL, dtype: object,
#  Region           Middle East & North Africa
#  Income Group                    High income
#  Special Notes                           NaN
#  Name: ISR, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: ITA, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes                          NaN
#  Name: JAM, dtype: object,
#  Region                                  Middle East & North Africa
#  Income Group                                   Upper middle income
#  Special Notes    Expenditure data from 2010 removed as they are...
#  Name: JOR, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                           High income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: JPN, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Upper middle income
#  Special Notes                      NaN
#  Name: KAZ, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                   Lower middle income
#  Special Notes    Fiscal year end: June 30; reporting period for...
#  Name: KEN, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Lower middle income
#  Special Notes                      NaN
#  Name: KGZ, dtype: object,
#  Region           East Asia & Pacific
#  Income Group     Lower middle income
#  Special Notes                    NaN
#  Name: KHM, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                   Lower middle income
#  Special Notes    Based on IMF and World Bank Country team, GDP ...
#  Name: KIR, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group                   High income
#  Special Notes                          NaN
#  Name: KNA, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                           High income
#  Special Notes    The new base year is 2010. GDP data are availa...
#  Name: KOR, dtype: object,
#  Region                                  Middle East & North Africa
#  Income Group                                           High income
#  Special Notes    Fiscal year end: June 30; reporting period for...
#  Name: KWT, dtype: object,
#  Region           East Asia & Pacific
#  Income Group     Lower middle income
#  Special Notes    New base Year 2012.
#  Name: LAO, dtype: object,
#  Region                Middle East & North Africa
#  Income Group                 Upper middle income
#  Special Notes    The new reference year is 2010.
#  Name: LBN, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                            Low income
#  Special Notes    National accounts local currency data have bee...
#  Name: LBR, dtype: object,
#  Region                                  Middle East & North Africa
#  Income Group                                   Upper middle income
#  Special Notes    Official statistics for Libya are not availabl...
#  Name: LBY, dtype: object,
#  Region                                   Latin America & Caribbean
#  Income Group                                   Upper middle income
#  Special Notes    St. Lucia has changed the data source from Eas...
#  Name: LCA, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: LIE, dtype: object,
#  Region                                                  South Asia
#  Income Group                                   Lower middle income
#  Special Notes    Bureau of Census and Statistics revised nation...
#  Name: LKA, dtype: object,
#  Region                                          Sub-Saharan Africa
#  Income Group                                   Lower middle income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: LSO, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: LTU, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: LUX, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: LVA, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                           High income
#  Special Notes    On 20 December 1999 China resumed its exercise...
#  Name: MAC, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group                   High income
#  Special Notes                          NaN
#  Name: MAF, dtype: object,
#  Region           Middle East & North Africa
#  Income Group            Lower middle income
#  Special Notes                           NaN
#  Name: MAR, dtype: object,
#  Region           Europe & Central Asia
#  Income Group               High income
#  Special Notes                      NaN
#  Name: MCO, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Lower middle income
#  Special Notes                      NaN
#  Name: MDA, dtype: object,
#  Region           Sub-Saharan Africa
#  Income Group             Low income
#  Special Notes                   NaN
#  Name: MDG, dtype: object,
#  Region                    South Asia
#  Income Group     Upper middle income
#  Special Notes                    NaN
#  Name: MDV, dtype: object,
#  Region           Latin America & Caribbean
#  Income Group           Upper middle income
#  Special Notes                          NaN
#  Name: MEX, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                   Upper middle income
#  Special Notes    Fiscal year ends on September 30; reporting pe...
#  Name: MHL, dtype: object,
#  Region           Europe & Central Asia
#  Income Group       Upper middle income
#  Special Notes                      NaN
#  Name: MKD, dtype: object,
#  Region                   Sub-Saharan Africa
#  Income Group                     Low income
#  Special Notes    The new base year is 1999.
#  Name: MLI, dtype: object,
#  Region                                  Middle East & North Africa
#  Income Group                                           High income
#  Special Notes    A simple multiplier is used to convert the nat...
#  Name: MLT, dtype: object,
#  Region                                         East Asia & Pacific
#  Income Group                                   Lower middle income
#  Special Notes    Fiscal year end: March 31; reporting period fo...
#  Name: MMR, dtype: object,
#  Region                                       Europe & Central Asia
#  Income Group                                   Upper middle income
#  Special Notes    Montenegro declared independence from Serbia a...
#  Name: MNE, dtype: object,
#  ...]

# %% [markdown]
# ***Expected output***
#
# ```python
# find_countries_by_region_and_income('South Asia','High income')==None
# find_countries_by_region_and_income('Europe & Central Asia','Low income')==['Tajikistan']
# find_countries_by_region_and_income('Sub-Saharan Africa','Upper middle income')==['Botswana','Gabon','Equatorial Guinea','Mauritius','Namibia','South Africa']
# ```

# %%
df = pd.DataFrame({'c1': [10, 11, 12], 'c2': [100, 110, 120]})
df = df.reset_index()  # make sure indexes pair with number of rows

for index, row in df.iterrows():
    print(row['c1'], row['c2'])
# Out:
# 10 100
# 11 110
# 12 120
