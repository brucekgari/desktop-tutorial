# %% [markdown]
# # Optimised SQL Queries: Flights Database
# © Explore Data Science Academy

# %% [markdown]
# ## Instructions to Students
#
# This challenge is designed to determine how much you have learned so far and will test your knowledge on Optimised SQL queries.
#
# The answers for this challenge should be selected on Athena for each corresponding Multiple Choice Question. The questions are included in this notebook and are numbered according to the Athena Questions, the options to choose from for each question has also been included.
#
# Do not add or remove cells in this notebook. Do not edit or remove the `%%sql` comment as it is required to run each cell.
#
# **_Good Luck!_**

# %% [markdown]
# ## Honour Code
#
# I YOUR NAME, YOUR SURNAME, confirm - by submitting this document - that the solutions in this notebook are a result of my own work and that I abide by the EDSA honour code (https://drive.google.com/file/d/1QDCjGZJ8-FmJE3bZdIQNwnJyQKPhHZBn/view?usp=sharing).
#
# Non-compliance with the honour code constitutes a material breach of contract.

# %% [markdown]
# ## The flights database
#
# Optimised queries are vital for increasing database performance, saving resources and reducing network overhead. In this challenge we will be  using actual US flights data to illustrate the use of optimisation techniques with large amounts of data. This database consists of information relating to flights, carriers, airports and planes.
#
# <img src="https://github.com/Explore-AI/Pictures/blob/master/Flights.jpg?raw=true" width=50%/>
#
#
# Below is an Entity Relationship Diagram (ERD) of the flights database:
#
# <img src="https://github.com/Explore-AI/Pictures/blob/master/flights_ER_diagram.png?raw=true" width=40%/>
#
# As can be seen from the ERD, the flights database consists of four tables:
# - **flights**: all domestic flights in the USA in 2008
# - **carriers**: lookup table for all the carriers
# - **planes**: lookup table for all the planes
# - **airports**: lookup table for all the airports
#
# For this challenge you will apply the use of optimised SQL queries to gain insight into the flights database.

# %% [markdown]
# ## Loading the database
#
# Before you start producing optimised SQL queries, you need to prepare your SQL environment. You can do this by loading in the magic command `%load_ext sql` as we've seen in previous trains. Next you can go ahead and load in your database. To do this you will need to ensure you have downloaded the `flight.db`sqlite file from Athena and have stored it in a known location.

# %%
# %load_ext sql

# %%
# %%sql
#
# sqlite:///flights.db

# %% [markdown]
# ## Exploring the database
#
# Before we begin this challenge we can go ahead and take a look at the composition of each table in the flights database

# %%
# %%sql
#
# PRAGMA table_info(flights);
# Out:
#  * sqlite:///flights.db
# Done.
# [(0, 'index', 'INTEGER', 0, 'NULL', 0),
#  (1, 'Date', 'longtext', 0, None, 0),
#  (2, 'DayOfWeek', 'INTEGER', 0, 'NULL', 0),
#  (3, 'DepTime', 'double', 0, 'NULL', 0),
#  (4, 'CRSDepTime', 'longtext', 0, None, 0),
#  (5, 'ArrTime', 'double', 0, 'NULL', 0),
#  (6, 'CRSArrTime', 'longtext', 0, None, 0),
#  (7, 'UniqueCarrier', 'longtext', 0, None, 0),
#  (8, 'FlightNum', 'longtext', 0, None, 0),
#  (9, 'TailNum', 'longtext', 0, None, 0),
#  (10, 'ActualElapsedTime', 'double', 0, 'NULL', 0),
#  (11, 'CRSElapsedTime', 'longtext', 0, None, 0),
#  (12, 'AirTime', 'longtext', 0, None, 0),
#  (13, 'ArrDelay', 'double', 0, 'NULL', 0),
#  (14, 'DepDelay', 'double', 0, 'NULL', 0),
#  (15, 'Origin', 'longtext', 0, None, 0),
#  (16, 'Dest', 'longtext', 0, None, 0),
#  (17, 'Distance', 'INTEGER', 0, 'NULL', 0),
#  (18, 'TaxiIn', 'longtext', 0, None, 0),
#  (19, 'TaxiOut', 'longtext', 0, None, 0),
#  (20, 'Cancelled', 'longtext', 0, None, 0),
#  (21, 'CancellationCode', 'longtext', 0, None, 0),
#  (22, 'Diverted', 'longtext', 0, None, 0),
#  (23, 'CarrierDelay', 'longtext', 0, None, 0),
#  (24, 'WeatherDelay', 'longtext', 0, None, 0),
#  (25, 'NASDelay', 'longtext', 0, None, 0),
#  (26, 'SecurityDelay', 'longtext', 0, None, 0),
#  (27, 'LateAircraftDelay', 'longtext', 0, None, 0)]

# %%
# %%sql
#
# PRAGMA table_info(carriers);
# Out:
#  * sqlite:///flights.db
# Done.
# [(0, 'Code', 'varchar(10)', 0, 'NULL', 0),
#  (1, 'Description', 'varchar(100)', 0, 'NULL', 0)]

# %%
# %%sql
#
# PRAGMA table_info(airports);
# Out:
#  * sqlite:///flights.db
# Done.
# [(0, 'iata', 'varchar(10)', 0, 'NULL', 0),
#  (1, 'airport', 'varchar(100)', 0, 'NULL', 0),
#  (2, 'city', 'varchar(100)', 0, 'NULL', 0),
#  (3, 'state', 'varchar(50)', 0, 'NULL', 0),
#  (4, 'country', 'varchar(50)', 0, 'NULL', 0),
#  (5, 'lat', 'float(24,0)', 0, 'NULL', 0),
#  (6, 'long', 'float(24,0)', 0, 'NULL', 0)]

# %%
# %%sql
#
# PRAGMA table_info(planes);
# Out:
#  * sqlite:///flights.db
# Done.
# [(0, 'tailnum', 'varchar(10)', 0, 'NULL', 0),
#  (1, 'type', 'varchar(100)', 0, 'NULL', 0),
#  (2, 'manufacturer', 'varchar(100)', 0, 'NULL', 0),
#  (3, 'issue_date', 'varchar(100)', 0, 'NULL', 0),
#  (4, 'model', 'varchar(50)', 0, 'NULL', 0),
#  (5, 'status', 'varchar(100)', 0, 'NULL', 0),
#  (6, 'aircraft_type', 'varchar(100)', 0, 'NULL', 0),
#  (7, 'engine_type', 'varchar(100)', 0, 'NULL', 0),
#  (8, 'year', 'longtext', 0, None, 0)]

# %% [markdown]
# ## Questions on Optimised SQL Queries
#
# Now that you have an idea of what information each table contains, you can use the given cell below each question to execute your optimised SQL queries to find the correct output from the options provided for the multiple choice questions on Athena.

# %% [markdown]
# **Question 1**
#
# How many different carriers are there in total in the database?
#
# **Options:**
# - 1 252
# - 1491
# - 20
# - 37

# %%
# %%sql
#
# SELECT COUNT(DISTINCT(Description)) FROM carriers AS No_of_carriers;
# Out:
#  * sqlite:///flights.db
# Done.
# [(1491,)]

# %% [markdown]
# **Question 2**
#
# How long was the longest delay before departure?
#
# **Options:**
# - 1355 min
# - 999 min
# - 1099 min
# - 588 min

# %%
# %%sql
#
# SELECT MAX(DepDelay) FROM flights AS longest_delay;
# Out:
#  * sqlite:///flights.db
# Done.
# [(1355.0,)]

# %% [markdown]
# **Question 3**
#
# How many flights departed on the 28th of January 2008?
#
# **Options:**
# - 540 908
# - 20 149
# - 19 495
# - 18 056

# %%
# %%sql
#
# With CTE AS
# (SELECT FlightNum, Date, Cancelled FROM Flights)
# SELECT COUNT(FlightNum), Date
# FROM CTE
# WHERE Date = '2008/1/28'
#     AND Cancelled = '0';
# Out:
#  * sqlite:///flights.db
# Done.
# [(19495, '2008/1/28')]

# %% [markdown]
# **Question 4**
#
#  What is the distance between Midway Airport (MDW) and Houston Airport (HOU)?
#
#  **Options:**
#  - 611 km
#  - 972 km
#  - 1 121 km
#  - 937 km

# %%
# %%sql
#
# With CTE AS
# (SELECT Origin, Dest, Distance FROM Flights)
#
# SELECT * FROM CTE
# WHERE Origin = 'MDW'
#     AND Dest = 'HOU'
# LIMIT 1;
# Out:
#  * sqlite:///flights.db
# Done.
# [('MDW', 'HOU', 937)]

# %% [markdown]
# **Question 5**
#
# Which day of the week had the highest number of cancelled flights?(Note 1 = cancelled , 0 = not cancelled;)
#
#
# **Options:**
# - Monday(1)
# - Wednesday(3)
# - Saturday(6)
# - Thursday (4)

# %%
# %%sql
#
# With CTE AS
# (SELECT DayOfWeek, Cancelled FROM Flights)
#
# SELECT COUNT(DayOfWeek), DayOfWeek FROM CTE
# WHERE Cancelled = '1'
# GROUP BY DayOfWeek;
# Out:
#  * sqlite:///flights.db
# Done.
# [(2617, 1), (2993, 2), (2645, 3), (3093, 4), (2049, 5), (1984, 6), (1927, 7)]

# %% [markdown]
# **Question 6**
#
# How many airports have the word "International" in their name?
#
# **Options:**
# - 110
# - 124
# - 8
# - 2

# %%
# %%sql
#
# SELECT COUNT(airport) FROM airports
# WHERE airport LIKE '%international%';
# Out:
#  * sqlite:///flights.db
# Done.
# [(124,)]

# %% [markdown]
# **Question 7**
#
# What is the most produced model for the manufacturer "BOEING"?
#
# **Options:**
# - 717-200
# - 737-7H4
# - 757-222
# - 737-3H4

# %%
# %%sql
#
# With CTE AS
# (SELECT manufacturer, model FROM planes)
#
# SELECT manufacturer, model, COUNT(model) FROM CTE
# WHERE manufacturer = 'BOEING'
# GROUP BY model
# ORDER BY COUNT(model) DESC;
# Out:
#  * sqlite:///flights.db
# Done.
# [('BOEING', '737-7H4', 308),
#  ('BOEING', '737-3H4', 147),
#  ('BOEING', '757-232', 112),
#  ('BOEING', '737-824', 100),
#  ('BOEING', '717-200', 98),
#  ('BOEING', '757-222', 96),
#  ('BOEING', '767-332', 77),
#  ('BOEING', '737-832', 68),
#  ('BOEING', '737-322', 64),
#  ('BOEING', '737-524', 56),
#  ('BOEING', '777-222', 52),
#  ('BOEING', '737-3TO', 50),
#  ('BOEING', '757-251', 49),
#  ('BOEING', '757-224', 41),
#  ('BOEING', '737-724', 36),
#  ('BOEING', '767-322', 35),
#  ('BOEING', '737-890', 33),
#  ('BOEING', '737-7BD', 32),
#  ('BOEING', '737-522', 30),
#  ('BOEING', '767-323', 27),
#  ('BOEING', '757-223', 27),
#  ('BOEING', '737-76N', 27),
#  ('BOEING', '737-4B7', 27),
#  ('BOEING', '737-5H4', 25),
#  ('BOEING', '747-422', 23),
#  ('BOEING', '737-4Q8', 22),
#  ('BOEING', '767-432ER', 21),
#  ('BOEING', '737-3G7', 20),
#  ('BOEING', '737-790', 19),
#  ('BOEING', '757-2B7', 18),
#  ('BOEING', '767-424ER', 16),
#  ('BOEING', '757-351', 16),
#  ('BOEING', '737-490', 16),
#  ('BOEING', '737-3B7', 16),
#  ('BOEING', '767-223', 15),
#  ('BOEING', '757-225', 13),
#  ('BOEING', '737-401', 13),
#  ('BOEING', '777-224', 12),
#  ('BOEING', '737-990', 12),
#  ('BOEING', '737-924', 12),
#  ('BOEING', '767-224', 10),
#  ('BOEING', '757-324', 9),
#  ('BOEING', '757-2Q8', 9),
#  ('BOEING', '737-3Q8', 9),
#  ('BOEING', '737-3A4', 9),
#  ('BOEING', '777-232', 8),
#  ('BOEING', '767-33A', 8),
#  ('BOEING', '757-33N', 8),
#  ('BOEING', '737-924ER', 8),
#  ('BOEING', '737-301', 7),
#  ('BOEING', '767-3P6', 6),
#  ('BOEING', '757-2S7', 6),
#  ('BOEING', '757-231', 6),
#  ('BOEING', '737-3Y0', 6),
#  ('BOEING', '767-2B7', 5),
#  ('BOEING', '767-201', 5),
#  ('BOEING', '757-212', 4),
#  ('BOEING', '737-3S3', 4),
#  ('BOEING', '737-33A', 4),
#  ('BOEING', '737-317', 4),
#  ('BOEING', '737-236', 4),
#  ('BOEING', '767-3G5', 3),
#  ('BOEING', '767-3CB', 3),
#  ('BOEING', '757-2G7', 3),
#  ('BOEING', '757-23N', 3),
#  ('BOEING', '737-3T5', 3),
#  ('BOEING', '777-232LR', 2),
#  ('BOEING', '737-7Q8', 2),
#  ('BOEING', '737-76Q', 2),
#  ('BOEING', '737-73A', 2),
#  ('BOEING', '737-3L9', 2),
#  ('BOEING', '737-3K2', 2),
#  ('BOEING', '767-324', 1),
#  ('BOEING', '757-26D', 1),
#  ('BOEING', '747-451', 1),
#  ('BOEING', '747-2B5F', 1),
#  ('BOEING', '737-8FH', 1),
#  ('BOEING', '737-7AD', 1),
#  ('BOEING', '737-705', 1),
#  ('BOEING', '737-4S3', 1),
#  ('BOEING', '737-2Y5', 1),
#  ('BOEING', '737-2X6C', 1),
#  ('BOEING', '737-2P6', 1),
#  ('BOEING', '737-282C', 1),
#  ('BOEING', '737-282', 1),
#  ('BOEING', '737-230', 1)]

# %% [markdown]
# **Question 8**
#
# What manufacturer had the highest average delay time (DepDelay + ArrDelay)?
#
# **Options:**
# - PAIR MIKE E
# - AERONCA
# - AVIAT AIRCRAFT INC
# - BOEING OF CANADA LTD

# %%
# %%sql
#
# SELECT manufacturer, DepTime, ArrDelay
# FROM flights
# INNER JOIN planes
# ON flights.tailnum = planes.tailnum
# Out:
#  * sqlite:///flights.db
# Done.

# %% [markdown]
# **Question 9**
#
# How many planes landed at Los Angeles International Airport?
#
# **Options:**
# - 215 608
# - 18 514
# - 41 258
# - 39 422

# %%
# %%sql
#
# SELECT airport, iata, COUNT(Dest)
# FROM airports
# INNER JOIN flights
# ON airports.iata = flights.Dest
# WHERE airport = 'Los Angeles International'
#     AND Cancelled = '0';
# Out:
#  * sqlite:///flights.db
# Done.
# [('Los Angeles International', 'LAX', 18514)]

# %% [markdown]
# **Question 10**
#
# Which domestic carrier had the best on-time performance (OTP), where OTP is defined as the rate of on time flights with a 15min buffer on departure and arrival?
#
# **Options:**
# - American Airlines Inc
# - Hawaiian Airlines Inc
# - Comair Inc
# - Aloha Airlines Inc

# %%
# %%sql
#
# SELECT Description, DepTime, ArrTime
# FROM flights
# INNER JOIN carriers
# ON flights.UniqueCarrier = carriers.Code
# WHERE ArrTime - DepTime = 15
# Out:
#  * sqlite:///flights.db
# Done.
# [('Southwest Airlines Co.\r', 644.0, 659.0),
#  ('Southwest Airlines Co.\r', 706.0, 721.0),
#  ('Southwest Airlines Co.\r', 1927.0, 1942.0),
#  ('Southwest Airlines Co.\r', 1510.0, 1525.0),
#  ('Southwest Airlines Co.\r', 2231.0, 2246.0),
#  ('Southwest Airlines Co.\r', 1723.0, 1738.0),
#  ('Southwest Airlines Co.\r', 2135.0, 2150.0),
#  ('Southwest Airlines Co.\r', 618.0, 633.0),
#  ('Southwest Airlines Co.\r', 1536.0, 1551.0),
#  ('Southwest Airlines Co.\r', 1729.0, 1744.0),
#  ('Southwest Airlines Co.\r', 1541.0, 1556.0),
#  ('Southwest Airlines Co.\r', 1137.0, 1152.0),
#  ('Southwest Airlines Co.\r', 2234.0, 2249.0),
#  ('Southwest Airlines Co.\r', 807.0, 822.0),
#  ('Southwest Airlines Co.\r', 707.0, 722.0),
#  ('Southwest Airlines Co.\r', 2212.0, 2227.0),
#  ('Southwest Airlines Co.\r', 1238.0, 1253.0),
#  ('Southwest Airlines Co.\r', 1721.0, 1736.0),
#  ('Southwest Airlines Co.\r', 1811.0, 1826.0),
#  ('Southwest Airlines Co.\r', 1743.0, 1758.0),
#  ('Southwest Airlines Co.\r', 1021.0, 1036.0),
#  ('Southwest Airlines Co.\r', 830.0, 845.0),
#  ('Southwest Airlines Co.\r', 743.0, 758.0),
#  ('Southwest Airlines Co.\r', 1622.0, 1637.0),
#  ('Southwest Airlines Co.\r', 1916.0, 1931.0),
#  ('Southwest Airlines Co.\r', 1305.0, 1320.0),
#  ('Southwest Airlines Co.\r', 1726.0, 1741.0),
#  ('Southwest Airlines Co.\r', 1441.0, 1456.0),
#  ('Southwest Airlines Co.\r', 1814.0, 1829.0),
#  ('Southwest Airlines Co.\r', 1315.0, 1330.0),
#  ('Southwest Airlines Co.\r', 2120.0, 2135.0),
#  ('Southwest Airlines Co.\r', 1843.0, 1858.0),
#  ('Southwest Airlines Co.\r', 631.0, 646.0),
#  ('Southwest Airlines Co.\r', 835.0, 850.0),
#  ('Southwest Airlines Co.\r', 2032.0, 2047.0),
#  ('Southwest Airlines Co.\r', 706.0, 721.0),
#  ('Southwest Airlines Co.\r', 1606.0, 1621.0),
#  ('Southwest Airlines Co.\r', 1129.0, 1144.0),
#  ('Southwest Airlines Co.\r', 701.0, 716.0),
#  ('Southwest Airlines Co.\r', 1428.0, 1443.0),
#  ('Southwest Airlines Co.\r', 830.0, 845.0),
#  ('Southwest Airlines Co.\r', 1830.0, 1845.0),
#  ('Southwest Airlines Co.\r', 1003.0, 1018.0),
#  ('Southwest Airlines Co.\r', 2018.0, 2033.0),
#  ('Southwest Airlines Co.\r', 902.0, 917.0),
#  ('Southwest Airlines Co.\r', 1434.0, 1449.0),
#  ('Southwest Airlines Co.\r', 1939.0, 1954.0),
#  ('Southwest Airlines Co.\r', 2208.0, 2223.0),
#  ('Southwest Airlines Co.\r', 1019.0, 1034.0),
#  ('Southwest Airlines Co.\r', 1224.0, 1239.0),
#  ('Southwest Airlines Co.\r', 1830.0, 1845.0),
#  ('Southwest Airlines Co.\r', 2007.0, 2022.0),
#  ('Southwest Airlines Co.\r', 1830.0, 1845.0),
#  ('Southwest Airlines Co.\r', 1706.0, 1721.0),
#  ('Southwest Airlines Co.\r', 1813.0, 1828.0),
#  ('Southwest Airlines Co.\r', 1807.0, 1822.0),
#  ('Southwest Airlines Co.\r', 1909.0, 1924.0),
#  ('Southwest Airlines Co.\r', 1234.0, 1249.0),
#  ('Southwest Airlines Co.\r', 1105.0, 1120.0),
#  ('Southwest Airlines Co.\r', 1630.0, 1645.0),
#  ('Southwest Airlines Co.\r', 919.0, 934.0),
#  ('Southwest Airlines Co.\r', 1616.0, 1631.0),
#  ('Southwest Airlines Co.\r', 901.0, 916.0),
#  ('Southwest Airlines Co.\r', 2039.0, 2054.0),
#  ('Southwest Airlines Co.\r', 1939.0, 1954.0),
#  ('Southwest Airlines Co.\r', 1016.0, 1031.0),
#  ('Southwest Airlines Co.\r', 1802.0, 1817.0),
#  ('Southwest Airlines Co.\r', 1139.0, 1154.0),
#  ('Southwest Airlines Co.\r', 903.0, 918.0),
#  ('Southwest Airlines Co.\r', 1803.0, 1818.0),
#  ('Southwest Airlines Co.\r', 1227.0, 1242.0),
#  ('Southwest Airlines Co.\r', 1014.0, 1029.0),
#  ('Southwest Airlines Co.\r', 1219.0, 1234.0),
#  ('Southwest Airlines Co.\r', 714.0, 729.0),
#  ('Southwest Airlines Co.\r', 1817.0, 1832.0),
#  ('Southwest Airlines Co.\r', 2120.0, 2135.0),
#  ('Southwest Airlines Co.\r', 1119.0, 1134.0),
#  ('Southwest Airlines Co.\r', 1220.0, 1235.0),
#  ('Southwest Airlines Co.\r', 906.0, 921.0),
#  ('Southwest Airlines Co.\r', 2213.0, 2228.0),
#  ('Southwest Airlines Co.\r', 1810.0, 1825.0),
#  ('Southwest Airlines Co.\r', 1024.0, 1039.0),
#  ('Southwest Airlines Co.\r', 1941.0, 1956.0),
#  ('Southwest Airlines Co.\r', 1631.0, 1646.0),
#  ('Southwest Airlines Co.\r', 842.0, 857.0),
#  ('Southwest Airlines Co.\r', 1505.0, 1520.0),
#  ('Southwest Airlines Co.\r', 1823.0, 1838.0),
#  ('Southwest Airlines Co.\r', 713.0, 728.0),
#  ('Southwest Airlines Co.\r', 1122.0, 1137.0),
#  ('Southwest Airlines Co.\r', 1904.0, 1919.0),
#  ('Southwest Airlines Co.\r', 732.0, 747.0),
#  ('Southwest Airlines Co.\r', 1932.0, 1947.0),
#  ('Southwest Airlines Co.\r', 901.0, 916.0),
#  ('Southwest Airlines Co.\r', 1406.0, 1421.0),
#  ('Southwest Airlines Co.\r', 1217.0, 1232.0),
#  ('Southwest Airlines Co.\r', 1340.0, 1355.0),
#  ('Southwest Airlines Co.\r', 1902.0, 1917.0),
#  ('Southwest Airlines Co.\r', 835.0, 850.0),
#  ('Southwest Airlines Co.\r', 920.0, 935.0),
#  ('Southwest Airlines Co.\r', 1618.0, 1633.0),
#  ('Southwest Airlines Co.\r', 1413.0, 1428.0),
#  ('Southwest Airlines Co.\r', 906.0, 921.0),
#  ('Southwest Airlines Co.\r', 1018.0, 1033.0),
#  ('Southwest Airlines Co.\r', 639.0, 654.0),
#  ('Southwest Airlines Co.\r', 841.0, 856.0),
#  ('Southwest Airlines Co.\r', 1417.0, 1432.0),
#  ('Southwest Airlines Co.\r', 1813.0, 1828.0),
#  ('Expressjet Airlines Inc.\r', 1402.0, 1417.0),
#  ('Expressjet Airlines Inc.\r', 1307.0, 1322.0),
#  ('Expressjet Airlines Inc.\r', 1640.0, 1655.0),
#  ('Expressjet Airlines Inc.\r', 1222.0, 1237.0),
#  ('Expressjet Airlines Inc.\r', 1211.0, 1226.0),
#  ('Mesa Airlines Inc.\r', 2228.0, 2243.0),
#  ('Mesa Airlines Inc.\r', 1140.0, 1155.0),
#  ('Mesa Airlines Inc.\r', 25.0, 40.0),
#  ('Mesa Airlines Inc.\r', 1630.0, 1645.0),
#  ('Mesa Airlines Inc.\r', 2225.0, 2240.0),
#  ('Mesa Airlines Inc.\r', 600.0, 615.0),
#  ('Mesa Airlines Inc.\r', 1624.0, 1639.0),
#  ('Mesa Airlines Inc.\r', 2220.0, 2235.0),
#  ('Mesa Airlines Inc.\r', 1100.0, 1115.0),
#  ('Mesa Airlines Inc.\r', 1935.0, 1950.0),
#  ('Mesa Airlines Inc.\r', 2224.0, 2239.0),
#  ('Mesa Airlines Inc.\r', 1311.0, 1326.0),
#  ('Mesa Airlines Inc.\r', 1600.0, 1615.0),
#  ('Mesa Airlines Inc.\r', 1105.0, 1120.0),
#  ('Mesa Airlines Inc.\r', 600.0, 615.0),
#  ('Mesa Airlines Inc.\r', 1430.0, 1445.0),
#  ('Mesa Airlines Inc.\r', 1140.0, 1155.0),
#  ('Mesa Airlines Inc.\r', 1511.0, 1526.0),
#  ('Mesa Airlines Inc.\r', 1635.0, 1650.0),
#  ('Mesa Airlines Inc.\r', 1425.0, 1440.0),
#  ('Mesa Airlines Inc.\r', 824.0, 839.0),
#  ('Mesa Airlines Inc.\r', 1825.0, 1840.0),
#  ('Mesa Airlines Inc.\r', 1934.0, 1949.0),
#  ('Mesa Airlines Inc.\r', 2225.0, 2240.0),
#  ('Mesa Airlines Inc.\r', 1605.0, 1620.0),
#  ('Comair Inc.\r', 2010.0, 2025.0),
#  ('Comair Inc.\r', 910.0, 925.0),
#  ('Comair Inc.\r', 1700.0, 1715.0),
#  ('Comair Inc.\r', 2010.0, 2025.0),
#  ('Comair Inc.\r', 2111.0, 2126.0),
#  ('Comair Inc.\r', 1305.0, 1320.0),
#  ('Comair Inc.\r', 920.0, 935.0),
#  ('Comair Inc.\r', 705.0, 720.0),
#  ('Comair Inc.\r', 708.0, 723.0),
#  ('Comair Inc.\r', 2015.0, 2030.0),
#  ('Comair Inc.\r', 1306.0, 1321.0),
#  ('Comair Inc.\r', 910.0, 925.0),
#  ('Comair Inc.\r', 1310.0, 1325.0),
#  ('Comair Inc.\r', 1638.0, 1653.0),
#  ('Comair Inc.\r', 1305.0, 1320.0),
#  ('Comair Inc.\r', 1320.0, 1335.0),
#  ('Comair Inc.\r', 1640.0, 1655.0),
#  ('Comair Inc.\r', 1225.0, 1240.0),
#  ('Comair Inc.\r', 2010.0, 2025.0),
#  ('Comair Inc.\r', 2110.0, 2125.0),
#  ('Comair Inc.\r', 1530.0, 1545.0),
#  ('Comair Inc.\r', 1305.0, 1320.0),
#  ('Comair Inc.\r', 1505.0, 1520.0),
#  ('Skywest Airlines Inc.\r', 932.0, 947.0),
#  ('Skywest Airlines Inc.\r', 1013.0, 1028.0),
#  ('Skywest Airlines Inc.\r', 711.0, 726.0),
#  ('Skywest Airlines Inc.\r', 1802.0, 1817.0),
#  ('Skywest Airlines Inc.\r', 815.0, 830.0),
#  ('Skywest Airlines Inc.\r', 1209.0, 1224.0),
#  ('Skywest Airlines Inc.\r', 2015.0, 2030.0),
#  ('Skywest Airlines Inc.\r', 1600.0, 1615.0),
#  ('Skywest Airlines Inc.\r', 1832.0, 1847.0),
#  ('Skywest Airlines Inc.\r', 1525.0, 1540.0),
#  ('Skywest Airlines Inc.\r', 1015.0, 1030.0),
#  ('Skywest Airlines Inc.\r', 2019.0, 2034.0),
#  ('Skywest Airlines Inc.\r', 2019.0, 2034.0),
#  ('Skywest Airlines Inc.\r', 1106.0, 1121.0),
#  ('Skywest Airlines Inc.\r', 1419.0, 1434.0),
#  ('Skywest Airlines Inc.\r', 812.0, 827.0),
#  ('Skywest Airlines Inc.\r', 2001.0, 2016.0),
#  ('Skywest Airlines Inc.\r', 600.0, 615.0),
#  ('Skywest Airlines Inc.\r', 1026.0, 1041.0),
#  ('Skywest Airlines Inc.\r', 1516.0, 1531.0),
#  ('Skywest Airlines Inc.\r', 820.0, 835.0),
#  ('Skywest Airlines Inc.\r', 1416.0, 1431.0),
#  ('Skywest Airlines Inc.\r', 2034.0, 2049.0),
#  ('Skywest Airlines Inc.\r', 1740.0, 1755.0),
#  ('Skywest Airlines Inc.\r', 1412.0, 1427.0),
#  ('Skywest Airlines Inc.\r', 1413.0, 1428.0),
#  ('United Air Lines Inc.\r', 1539.0, 1554.0),
#  ('United Air Lines Inc.\r', 815.0, 830.0),
#  ('United Air Lines Inc.\r', 725.0, 740.0),
#  ('United Air Lines Inc.\r', 822.0, 837.0),
#  ('United Air Lines Inc.\r', 813.0, 828.0),
#  ('United Air Lines Inc.\r', 1030.0, 1045.0),
#  ('United Air Lines Inc.\r', 1714.0, 1729.0),
#  ('United Air Lines Inc.\r', 1934.0, 1949.0),
#  ('United Air Lines Inc.\r', 1923.0, 1938.0),
#  ('United Air Lines Inc.\r', 625.0, 640.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 2310.0, 2325.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 1437.0, 1452.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 2136.0, 2151.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 819.0, 834.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 1124.0, 1139.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 1513.0, 1528.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 1430.0, 1445.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 2301.0, 2316.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 1119.0, 1134.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 1429.0, 1444.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 822.0, 837.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 1433.0, 1448.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 2112.0, 2127.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 1108.0, 1123.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 2108.0, 2123.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 824.0, 839.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 1829.0, 1844.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 2223.0, 2238.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 1433.0, 1448.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 2302.0, 2317.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 1436.0, 1451.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 1126.0, 1141.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 1116.0, 1131.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 1115.0, 1130.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 2242.0, 2257.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 1819.0, 1834.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 828.0, 843.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 2243.0, 2258.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 2124.0, 2139.0),
#  ('US Airways Inc. (Merged with America West 9/05. Reporting for both starting 10/07.)\r', 1517.0, 1532.0),
#  ('Southwest Airlines Co.\r', 2028.0, 2043.0),
#  ('Southwest Airlines Co.\r', 2315.0, 2330.0),
#  ('Southwest Airlines Co.\r', 842.0, 857.0),
#  ('Southwest Airlines Co.\r', 801.0, 816.0),
#  ('Southwest Airlines Co.\r', 1935.0, 1950.0),
#  ('Southwest Airlines Co.\r', 2306.0, 2321.0),
#  ('Southwest Airlines Co.\r', 716.0, 731.0),
#  ('Southwest Airlines Co.\r', 702.0, 717.0),
#  ('Southwest Airlines Co.\r', 2126.0, 2141.0),
#  ('Southwest Airlines Co.\r', 1611.0, 1626.0),
#  ('Delta Air Lines Inc.\r', 2011.0, 2026.0),
#  ('Delta Air Lines Inc.\r', 1605.0, 1620.0),
#  ('Delta Air Lines Inc.\r', 1338.0, 1353.0),
#  ('Delta Air Lines Inc.\r', 1716.0, 1731.0),
#  ('Delta Air Lines Inc.\r', 2109.0, 2124.0),
#  ('Delta Air Lines Inc.\r', 1936.0, 1951.0),
#  ('Delta Air Lines Inc.\r', 2028.0, 2043.0),
#  ('Delta Air Lines Inc.\r', 1935.0, 1950.0),
#  ('Delta Air Lines Inc.\r', 2010.0, 2025.0),
#  ('Delta Air Lines Inc.\r', 1612.0, 1627.0),
#  ('Delta Air Lines Inc.\r', 1432.0, 1447.0),
#  ('Delta Air Lines Inc.\r', 2008.0, 2023.0),
#  ('Delta Air Lines Inc.\r', 1615.0, 1630.0),
#  ('Atlantic Southeast Airlines\r', 2010.0, 2025.0),
#  ('Atlantic Southeast Airlines\r', 1938.0, 1953.0),
#  ('Atlantic Southeast Airlines\r', 1903.0, 1918.0),
#  ('Atlantic Southeast Airlines\r', 1525.0, 1540.0),
#  ('Atlantic Southeast Airlines\r', 1509.0, 1524.0),
#  ('Atlantic Southeast Airlines\r', 1230.0, 1245.0),
#  ('Atlantic Southeast Airlines\r', 1027.0, 1042.0),
#  ('Atlantic Southeast Airlines\r', 1920.0, 1935.0),
#  ('Atlantic Southeast Airlines\r', 1915.0, 1930.0),
#  ('Atlantic Southeast Airlines\r', 1920.0, 1935.0),
#  ('Atlantic Southeast Airlines\r', 2023.0, 2038.0),
#  ('Atlantic Southeast Airlines\r', 1628.0, 1643.0),
#  ('Atlantic Southeast Airlines\r', 1622.0, 1637.0),
#  ('Atlantic Southeast Airlines\r', 1633.0, 1648.0),
#  ('Atlantic Southeast Airlines\r', 830.0, 845.0),
#  ('Atlantic Southeast Airlines\r', 1430.0, 1445.0),
#  ('Atlantic Southeast Airlines\r', 1410.0, 1425.0),
#  ('Atlantic Southeast Airlines\r', 2115.0, 2130.0),
#  ('Atlantic Southeast Airlines\r', 2105.0, 2120.0),
#  ('Atlantic Southeast Airlines\r', 2120.0, 2135.0),
#  ('Atlantic Southeast Airlines\r', 920.0, 935.0),
#  ('Atlantic Southeast Airlines\r', 910.0, 925.0),
#  ('Atlantic Southeast Airlines\r', 1344.0, 1359.0),
#  ('Atlantic Southeast Airlines\r', 1823.0, 1838.0),
#  ('Atlantic Southeast Airlines\r', 1000.0, 1015.0),
#  ('Atlantic Southeast Airlines\r', 2225.0, 2240.0),
#  ('Atlantic Southeast Airlines\r', 1040.0, 1055.0),
#  ('Atlantic Southeast Airlines\r', 943.0, 958.0),
#  ('Atlantic Southeast Airlines\r', 1013.0, 1028.0),
#  ('Atlantic Southeast Airlines\r', 2230.0, 2245.0),
#  ('Atlantic Southeast Airlines\r', 2227.0, 2242.0),
#  ('Atlantic Southeast Airlines\r', 2235.0, 2250.0),
#  ('Atlantic Southeast Airlines\r', 2302.0, 2317.0),
#  ('Atlantic Southeast Airlines\r', 1123.0, 1138.0),
#  ('Atlantic Southeast Airlines\r', 1039.0, 1054.0),
#  ('Atlantic Southeast Airlines\r', 1142.0, 1157.0),
#  ('Atlantic Southeast Airlines\r', 1405.0, 1420.0),
#  ('Atlantic Southeast Airlines\r', 710.0, 725.0),
#  ('Atlantic Southeast Airlines\r', 830.0, 845.0),
#  ('Atlantic Southeast Airlines\r', 830.0, 845.0),
#  ('Atlantic Southeast Airlines\r', 2043.0, 2058.0),
#  ('Atlantic Southeast Airlines\r', 2023.0, 2038.0),
#  ('Atlantic Southeast Airlines\r', 1804.0, 1819.0),
#  ('Atlantic Southeast Airlines\r', 1421.0, 1436.0),
#  ('AirTran Airways Corporation\r', 930.0, 945.0),
#  ('AirTran Airways Corporation\r', 927.0, 942.0),
#  ('AirTran Airways Corporation\r', 1218.0, 1233.0),
#  ('AirTran Airways Corporation\r', 1721.0, 1736.0),
#  ('AirTran Airways Corporation\r', 2117.0, 2132.0),
#  ('AirTran Airways Corporation\r', 1741.0, 1756.0),
#  ('AirTran Airways Corporation\r', 1620.0, 1635.0),
#  ('AirTran Airways Corporation\r', 1736.0, 1751.0),
#  ('AirTran Airways Corporation\r', 1941.0, 1956.0),
#  ('AirTran Airways Corporation\r', 1224.0, 1239.0),
#  ('AirTran Airways Corporation\r', 922.0, 937.0),
#  ('AirTran Airways Corporation\r', 1908.0, 1923.0),
#  ('AirTran Airways Corporation\r', 1622.0, 1637.0),
#  ('AirTran Airways Corporation\r', 1923.0, 1938.0),
#  ('AirTran Airways Corporation\r', 915.0, 930.0),
#  ('AirTran Airways Corporation\r', 2111.0, 2126.0),
#  ('American Eagle Airlines Inc.\r', 1225.0, 1240.0),
#  ('American Eagle Airlines Inc.\r', 603.0, 618.0),
#  ('American Eagle Airlines Inc.\r', 1102.0, 1117.0),
#  ('American Eagle Airlines Inc.\r', 1914.0, 1929.0),
#  ('American Eagle Airlines Inc.\r', 1102.0, 1117.0),
#  ('American Eagle Airlines Inc.\r', 1120.0, 1135.0),
#  ('American Eagle Airlines Inc.\r', 1429.0, 1444.0),
#  ('American Eagle Airlines Inc.\r', 636.0, 651.0),
#  ('American Eagle Airlines Inc.\r', 702.0, 717.0),
#  ('American Eagle Airlines Inc.\r', 928.0, 943.0),
#  ('American Eagle Airlines Inc.\r', 718.0, 733.0),
#  ('American Eagle Airlines Inc.\r', 915.0, 930.0),
#  ('American Eagle Airlines Inc.\r', 911.0, 926.0),
#  ('American Eagle Airlines Inc.\r', 613.0, 628.0),
#  ('American Eagle Airlines Inc.\r', 605.0, 620.0),
#  ('American Eagle Airlines Inc.\r', 610.0, 625.0),
#  ('American Eagle Airlines Inc.\r', 1119.0, 1134.0),
#  ('American Eagle Airlines Inc.\r', 1121.0, 1136.0),
#  ('American Eagle Airlines Inc.\r', 1715.0, 1730.0),
#  ('American Eagle Airlines Inc.\r', 822.0, 837.0),
#  ('American Eagle Airlines Inc.\r', 1921.0, 1936.0),
#  ('American Eagle Airlines Inc.\r', 931.0, 946.0),
#  ('American Eagle Airlines Inc.\r', 925.0, 940.0),
#  ('American Eagle Airlines Inc.\r', 1600.0, 1615.0),
#  ('American Eagle Airlines Inc.\r', 613.0, 628.0),
#  ('American Eagle Airlines Inc.\r', 1143.0, 1158.0),
#  ('American Eagle Airlines Inc.\r', 600.0, 615.0),
#  ('American Eagle Airlines Inc.\r', 603.0, 618.0),
#  ('American Eagle Airlines Inc.\r', 1136.0, 1151.0),
#  ('American Eagle Airlines Inc.\r', 600.0, 615.0),
#  ('American Eagle Airlines Inc.\r', 625.0, 640.0),
#  ('American Eagle Airlines Inc.\r', 1318.0, 1333.0),
#  ('American Eagle Airlines Inc.\r', 1726.0, 1741.0),
#  ('American Eagle Airlines Inc.\r', 1430.0, 1445.0),
#  ('American Eagle Airlines Inc.\r', 1344.0, 1359.0),
#  ('Northwest Airlines Inc.\r', 1717.0, 1732.0),
#  ('Northwest Airlines Inc.\r', 1722.0, 1737.0),
#  ('Northwest Airlines Inc.\r', 1922.0, 1937.0),
#  ('Northwest Airlines Inc.\r', 2242.0, 2257.0),
#  ('Northwest Airlines Inc.\r', 914.0, 929.0),
#  ('Northwest Airlines Inc.\r', 1935.0, 1950.0),
#  ('Northwest Airlines Inc.\r', 1528.0, 1543.0),
#  ('Northwest Airlines Inc.\r', 1711.0, 1726.0),
#  ('Northwest Airlines Inc.\r', 1213.0, 1228.0),
#  ('Northwest Airlines Inc.\r', 1926.0, 1941.0),
#  ('Northwest Airlines Inc.\r', 1708.0, 1723.0),
#  ('Northwest Airlines Inc.\r', 1706.0, 1721.0),
#  ('Northwest Airlines Inc.\r', 907.0, 922.0),
#  ('Northwest Airlines Inc.\r', 1229.0, 1244.0),
#  ('Northwest Airlines Inc.\r', 1911.0, 1926.0),
#  ('Northwest Airlines Inc.\r', 1210.0, 1225.0),
#  ('Northwest Airlines Inc.\r', 1209.0, 1224.0),
#  ('Northwest Airlines Inc.\r', 921.0, 936.0),
#  ('Northwest Airlines Inc.\r', 1703.0, 1718.0),
#  ('Northwest Airlines Inc.\r', 1905.0, 1920.0),
#  ('Northwest Airlines Inc.\r', 919.0, 934.0),
#  ('Northwest Airlines Inc.\r', 918.0, 933.0),
#  ('Pinnacle Airlines Inc.\r', 1001.0, 1016.0),
#  ('Pinnacle Airlines Inc.\r', 904.0, 919.0),
#  ('Pinnacle Airlines Inc.\r', 904.0, 919.0),
#  ('Pinnacle Airlines Inc.\r', 1918.0, 1933.0),
#  ('Pinnacle Airlines Inc.\r', 1211.0, 1226.0),
#  ('Pinnacle Airlines Inc.\r', 1904.0, 1919.0),
#  ('Pinnacle Airlines Inc.\r', 705.0, 720.0),
#  ('Pinnacle Airlines Inc.\r', 739.0, 754.0),
#  ('Pinnacle Airlines Inc.\r', 725.0, 740.0),
#  ('Pinnacle Airlines Inc.\r', 725.0, 740.0),
#  ('Pinnacle Airlines Inc.\r', 1226.0, 1241.0),
#  ('Pinnacle Airlines Inc.\r', 1731.0, 1746.0),
#  ('Pinnacle Airlines Inc.\r', 1725.0, 1740.0),
#  ('Pinnacle Airlines Inc.\r', 1718.0, 1733.0),
#  ('American Airlines Inc.\r', 2024.0, 2039.0),
#  ('American Airlines Inc.\r', 1736.0, 1751.0),
#  ('Alaska Airlines Inc.\r', 1510.0, 1525.0),
#  ('Delta Air Lines Inc.\r', 927.0, 942.0),
#  ('Delta Air Lines Inc.\r', 1612.0, 1627.0),
#  ('Delta Air Lines Inc.\r', 1601.0, 1616.0),
#  ('Delta Air Lines Inc.\r', 1343.0, 1358.0),
#  ('Delta Air Lines Inc.\r', 1120.0, 1135.0),
#  ('Delta Air Lines Inc.\r', 2114.0, 2129.0),
#  ('Delta Air Lines Inc.\r', 1933.0, 1948.0),
#  ('Delta Air Lines Inc.\r', 2008.0, 2023.0)]
