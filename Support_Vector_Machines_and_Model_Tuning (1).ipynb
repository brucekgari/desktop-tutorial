# %% [markdown]
# # Support vector machines and model tuning
#
# © Explore Data Science Academy

# %% [markdown]
# ## Learning Objectives
# In this train you will learn how to:
#
# - Understand the basics of the Support Vector Machine (SVM) model and how it works;
# - Fit a SVM classifier model using `sklearn` library and the `linear` and `rbf` kernels;
# - Understand and visualise the hyperplane of an SVM classifier model; and
# - Tune an SVM model using the `GridSearchCV` function.
#
# ## Outline
#
# This train is structured as follows:
#
# - Import the relevant packages for SVMs from `sklearn`;
# - Generate a synthetic dataset to practice on;
# - Instantiate and fit an SVM classifier model with a linear decision boundary;
# - Instantiate and fit an SVM classifier model a non-linear decision boundary; and
# - Tune an SVM classifier model through the use of `GridSearchCV`.

# %% [markdown]
# ## Support vector machine
#
# How do Support Vector Machines work? The concept itself is quite simple. Let's pretend that you want to classify data points into group $A$ or group $B$. To do this, an SVM will plot your labelled training data as points in space and will look for the widest, clearest gap between points belonging to group A and points belonging to group B. It will then use this newly identified dividing line (known as a hyperplane) and the margin around it to classify new observations. An unseen data point will be classified into group A or B depending on which side of the margin it is closest to.
#
# It's easy to do this when your data only has 2 features. You only need a simple one-dimensional decision boundary (which is basically a line) to classify the data. However, as more features get added the line needs to take on more dimensions, as a simple line will no longer work. A line only has one dimension. A flat shape has 2 dimensions. A 3D shape (unsurprisingly) has 3. What do we call something with 4 or more dimensions? In this case, it's a hyperplane. In SVM, the hyperplane will always have one less dimension ($-1$) than the number of input features ($p$), or a total of $(p-1)$ dimensions.
#
# To explain it in more technical terms, the basic idea of the SVM is to separate points using a $(p - 1)$ dimensional hyperplane. What does it mean to separate points? This means that the SVM will construct a decision boundary such that points on the left are assigned a label of $A$ and points on the right are assigned a label of $B$.  When finding this separating hyperplane we wish to maximise the distance of the nearest points to the hyperplane. The technical term for this is **maximum separating hyperplane**. The data points which dictate where the separating hyperplane goes are called **support vectors**. You can see a diagram of the margin, hyperplane and support vectors below:
#
# ![svm](https://blog-c7ff.kxcdn.com/blog/wp-content/uploads/2017/02/Margin.png)
#
# You can read more about SVMs and how they work [here](https://en.wikipedia.org/wiki/Support_vector_machine).
#
# SVMs are interesting models. Like logistic regression, they fit a linear decision boundary. However, unlike logistic regression, SVMs do this in a non-proabilistic way and are able to fit to non-linear data using an algorithm known as the [kernel trick](https://en.wikipedia.org/wiki/Kernel_method). Furthermore, SVMs can be used for both classification and regression. In `sklearn`, these are called `SVC` (Support Vector Classifier) and `SVR` (Support Vector Regression) respectively.
#
# One important note: SVC can also refer to Support Vector **Clustering**, so make sure you don't get the two confused!

# %% [markdown]
# ### Getting started
#
# First we import the libraries that we will need.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Generate synthetic data
#
# Now we'll generate a random dataset to experiment with.
#
# For those of you who are interested, we do this by taking a multi-dimensional
# standard normal distribution and defining classes separated by nested
# concentric multi-dimensional spheres such that roughly equal numbers of
# samples are in each class (quantiles of the $\chi^2$ distribution).
#
# The less technical explanation for this is that we've generated a donut shaped dataset, where the samples belonging to one class are generally located in the centre, and the samples belonging to the other class are generally located in the outer ring.
#
# **Note:** Don't worry if you don't understand how this works right now, the most important thing is to know that we have a synthetic data set with a specific structure.

# %%
from sklearn.datasets import make_gaussian_quantiles

# Set the feature dimensionality
p = 2

# Construct the dataset
X, y = make_gaussian_quantiles(cov=3.,
                                 n_samples=1000, n_features=p,
                                 n_classes=2, random_state=1)

# %% [markdown]
# Now let's perform the train/test split:

# %%
# get training and testing data 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Fit a SVM classifier with a linear decision boundary
# We are going to fit an SVC model with a `linear kernel`. This means that we are telling the SVC to fit the data using a linear decision boundary. Let's also take a look at the accuracy score:

# %%
from sklearn.svm import SVC

svc = SVC(kernel='linear')
svc.fit(X_train, y_train)
y_pred = svc.predict(X_test)

print("The accuracy score of the SVC is:", accuracy_score(y_test, y_pred))
print("\n\nClassification Report:\n\n", classification_report(y_test, y_pred))
# Out:
# The accuracy score of the SVC is: 0.6133333333333333
#
#
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.58      0.83      0.68       150
#            1       0.70      0.39      0.50       150
#
#     accuracy                           0.61       300
#    macro avg       0.64      0.61      0.59       300
# weighted avg       0.64      0.61      0.59       300

# %% [markdown]
# ### Plot the decision boundary for the SVC
# That accuracy score doesn't seem very good. Why do you think that is? To help us understand what's going on, we can use a visualisation.
#
# As mentioned before, the SVC calculates and implements a $p-1$ dimensional decision boundary (hyperplane) over the input features. Since we are only looking at 2 features (our synthetic dataset only has two features, or $p=2$), our hyperplane will only have 1 dimension ($p-1$), so it's going to look like a single line.
#
# It should be noted that if your model has more than 2 features, you can plot the hyperplane for any 2 features you choose. Below, we'll visualise the hyperplane for the two features in the dataset:

# %%
i = 0 # Feature 1
j = 1 # Feature 2

svc.fit(X[:, [i, j]], y)
fig = plt.figure(figsize=(8, 8))
ax1 = fig.add_subplot(111)
 
x_min, x_max = X[:, i].min(), X[:, i].max()
y_min, y_max = X[:, j].min(), X[:, j].max()
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 1000), np.linspace(y_min, y_max, 1000))

y_hat = svc.predict(np.concatenate((xx.reshape(-1,1), yy.reshape(-1,1)), axis=1))
y_hat = y_hat.reshape(xx.shape)

ax1.pcolormesh(xx, yy, y_hat, cmap=plt.cm.get_cmap('RdBu_r'))
ax1.scatter(X[:, i], X[:, j], c=y, edgecolors='k', cmap=plt.cm.get_cmap('RdBu_r'))
ax1.set_xlabel('Feature 1')
ax1.set_ylabel('Feature 2')
ax1.set_xlim(xx.min(), xx.max())
ax1.set_ylim(yy.min(), yy.max())
ax1.set_xticks(())
ax1.set_yticks(())
plt.show()

# %% [markdown]
# Do you see the problem here? The donut-shaped data is not `linearly separable`, i.e. a linear decision boundary is unable to adequately separate this data.
#
# So let's make use of SVM's [kernel trick](https://en.wikipedia.org/wiki/Kernel_method) to use a **non-linear** decision boundary instead.

# %% [markdown]
# ### Fit a SVC classifier with a non-linear decision boundary
#
# For the next section, we're going to use the rbf kernel, which allows the SVC to fit a non-linear decision boundary. You can read more about rbf [here](https://en.wikipedia.org/wiki/Radial_basis_function_kernel).
#
# Let's train a model on our synthetic data using the `rbf` kernel and see if it improves the accuracy:

# %%
svc = SVC(kernel='rbf')
svc.fit(X_train, y_train)
y_pred = svc.predict(X_test)

print("The accuracy score of the SVC is:", accuracy_score(y_test, y_pred))
print("\n\nClassification Report:\n\n",classification_report(y_test, y_pred))
# Out:
# The accuracy score of the SVC is: 0.9833333333333333
#
#
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       150
#            1       0.99      0.98      0.98       150
#
#     accuracy                           0.98       300
#    macro avg       0.98      0.98      0.98       300
# weighted avg       0.98      0.98      0.98       300

# %% [markdown]
# As you can see, this is a **much** better result. Let's visualise our decision boundary to see why.

# %% [markdown]
# ### Plot the decision boundary for the SVC using the non-linear rbf kernel
#
# Once again we will plot the 1 dimensional decision boundary between the 2 features present in our synthetic dataset:

# %%
i = 0 # Feature 1
j = 1 # Feature 2

svc.fit(X[:, [i, j]], y)
fig = plt.figure(figsize=(8, 8))
ax1 = fig.add_subplot(111)
 
x_min, x_max = X[:, i].min(), X[:, i].max()
y_min, y_max = X[:, j].min(), X[:, j].max()
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 1000), np.linspace(y_min, y_max, 1000))

y_hat = svc.predict(np.concatenate((xx.reshape(-1,1), yy.reshape(-1,1)), axis=1))
y_hat = y_hat.reshape(xx.shape)

ax1.pcolormesh(xx, yy, y_hat, cmap=plt.cm.get_cmap('RdBu_r'))
ax1.scatter(X[:, i], X[:, j], c=y, edgecolors='k', cmap=plt.cm.get_cmap('RdBu_r'))
ax1.set_xlabel('Feature 1')
ax1.set_ylabel('Feature 2')
ax1.set_xlim(xx.min(), xx.max())
ax1.set_ylim(yy.min(), yy.max())
ax1.set_xticks(())
ax1.set_yticks(())
plt.show()

# %% [markdown]
# Clearly the `rbf` kernel is a better fit to our data and results in a better performing model. If we didn't change our parameters and try a different kernel, we would have thought that our SVC did not perform well on the data and could possibly have discarded it. This highlights the importance of optimising the parameters of a model.
#
# Optimising a model is a well known concept and is known as **model tuning**. Fortunately `sklearn` provides some tools for us to do this easily.

# %% [markdown]
# ## Tuning an SVM model
#
# You have probably noticed that the models in the `sklearn` library have quite a few parameters, right? It's possible to use a process called **model tuning** to find the best possible set of parameters for a model. For this purpose we will use `sklearn`'s [GridSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html). This procedure allows us to specify a set of possible parameters for a specific model. `GridSearchCV` will then go through those parameters and try every possible combination of them (kind of like it's working through a grid in a systematic way - that's where the name comes from). `GridSearchCV` will then return the combination of parameters that resulted in a model with the best score.
#
# What metric does it use to calculate the score? It will depend on the model being tested, or if you specify your own metric. You should check out exactly how this works on your own! You should also note the `GridSearchCV` makes use of **cross validation**, helping to ensure the robustness of it's results.
#
# Lets try it out. The first thing to do is to create a dictionary that contains the parameters you want to tune as `keys` and all the different options you want to test for those parameters as `values`. Let's do that now:

# %%
parameters = {'kernel':('linear', 'rbf'), 
              'C':(0.25,1.0),
              'gamma': (1,2)}

# %% [markdown]
# Now, we instantiate an SVC classifier and tell `GridSearchCV` to test it using the parameters we previously specified:

# %%
svm = SVC()
clf = GridSearchCV(svm, parameters)
clf.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': (0.25, 1.0), 'gamma': (1, 2),
#                          'kernel': ('linear', 'rbf')},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %% [markdown]
# Now let's make some predictions using our newly tuned model:

# %%
y_opt = clf.predict(X_test)
print("The accuracy for our tuned model is: ", accuracy_score(y_test, y_opt))
# Out:
# The accuracy for our tuned model is:  0.9666666666666667

# %% [markdown]
# As you can see, thanks to `GridSearchCV` we were able to achieve a good result with much less effort!
#
# There are a few things to note about `GridSearchCV`. It takes a base model (in this case an SVC classifier) and grid of parameters (our `parameters` dictionary) as input. By default, `GridSearchCV` will continuously refit the model until it finds the model with best combination of parameters and will return it to the user. Here, we saved the best model as `clf`.
#
# You can also get the parameters of the best performing model as follows:

# %%
clf.best_params_
# Out:
# {'C': 1.0, 'gamma': 1, 'kernel': 'rbf'}

# %% [markdown]
# **Note**: Depending on the model you are choosing, the number of parameters you are tuning and the size and complexity of the dataset you are using `GridSearchCV` can take a lot of time and processing power to perform. Therefore, it's often wise to limit the number and range of the parameters you are testing at once.

# %% [markdown]
# ## Excercise
# Now try to experiment a little bit. Generate your own synthetic dataset with more features and dimensions (i.e.: $p>2$). To do this you can copy the code from above and change the `p` variable to a higher number. Then, fit your own SVC classifier and tune it using `GridSearchCV`. Does the accuracy improve? Or does it get worse? Why do you think this is the case? Try discussing it with your group.

# %% [markdown]
# ## Conclusion
#
# In this train we have seen or been introduced to:
#
# - The concept of SVMs and how they work;
# - How to fit an SVM classifier to data;
# - How the choice of kernel (and other parameters) can affect SVM model performance;
# - How to tune an SVM model using `GridSearchCV` and obtain optimised model parameters.
#
# In future trains, we will look at some other popular classification models and how to tune them.
